# %% [markdown]
# ## Time Series Forecasting Assignment
# ### Vasundhra

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Importing the dataset into pandas dataframe

# %%
df=pd.read_csv("AirPassengers.csv")

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
from datetime import datetime
from datetime import timedelta

# %%
df['year']=pd.to_datetime(df['Month'],format="%Y-%m")
df.set_index("year", inplace=True)

# %% [markdown]
# Plotting the data to observe trend, seasonality

# %%
plt.figure(figsize=(8,8))
df["#Passengers"].plot(grid=True)
plt.xlabel("Year",fontsize=12)
plt.ylabel("No of passengers",fontsize=12)
plt.show()

# %% [markdown]
# At first glance it can be observed that there is an upward trend. This is a clear indication that the time series parameters aren't remaining constant over time.

# %% [markdown]
# ### Rolling Statistics-Moving Average

# %%
df1=df.rename(columns={"#Passengers":"Passengers"})

# %%
df1['Moving Average']=df1.Passengers.rolling(12).mean()

# %%
df1["MA2"]=df1.Passengers.rolling(12).std()

# %%
df1
# Out:
#               Month  Passengers  Moving Average        MA2
# year
# 1949-01-01  1949-01         112             NaN        NaN
# 1949-02-01  1949-02         118             NaN        NaN
# 1949-03-01  1949-03         132             NaN        NaN
# 1949-04-01  1949-04         129             NaN        NaN
# 1949-05-01  1949-05         121             NaN        NaN
# ...             ...         ...             ...        ...
# 1960-08-01  1960-08         606      463.333333  83.630500
# 1960-09-01  1960-09         508      467.083333  84.617276
# 1960-10-01  1960-10         461      471.583333  82.541954
# 1960-11-01  1960-11         390      473.916667  79.502382
# 1960-12-01  1960-12         432      476.166667  77.737125
#
# [144 rows x 4 columns]

# %%
df1["Passengers"].plot(grid=True)
df1["Moving Average"].plot(grid=True)
df1["MA2"].plot(grid=True)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# From here it can be observed that moving mean has a positive slope which means the data has an upward trend. The standard deviation is relatively gradual in increasing. A period of 12 is chosen for plotting rolling statistics because the data depicts seasonal variation in every 12 months.

# %%
import statsmodels

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df1["Passengers"])
# Out:
# (0.8153688792060464,
#  0.991880243437641,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %% [markdown]
# The test statistic is greater than all 3 critical values. This clearly indicates non stationarity.

# %%
df1['log']=np.log(df1['Passengers'])

# %% [markdown]
# Log of values is taken to stabilize the variance of the series.

# %%
df1["1st difference"]=df1["log"].diff()

# %% [markdown]
# Since from above conclusions it is evident that the data has inherent upward trend, we perform differencing and calculate first difference.

# %%
df2=df1.dropna(axis=0)

# %%
df2.head()
# Out:
#               Month  Passengers  Moving Average        MA2       log  \
# year
# 1949-12-01  1949-12         118      126.666667  13.720147  4.770685
# 1950-01-01  1950-01         115      126.916667  13.453342  4.744932
# 1950-02-01  1950-02         126      127.583333  13.166475  4.836282
# 1950-03-01  1950-03         141      128.333333  13.686977  4.948760
# 1950-04-01  1950-04         135      128.833333  13.822467  4.905275
#
#             1st difference
# year
# 1949-12-01        0.126294
# 1950-01-01       -0.025752
# 1950-02-01        0.091350
# 1950-03-01        0.112478
# 1950-04-01       -0.043485

# %%
df2.shape
# Out:
# (133, 6)

# %%
adfuller(df2["1st difference"])
# Out:
# (-3.122207132743747,
#  0.024952817553355874,
#  13,
#  119,
#  {'1%': -3.4865346059036564,
#   '5%': -2.8861509858476264,
#   '10%': -2.579896092790057},
#  -415.8416142161042)

# %% [markdown]
# The test statistic (-3.122) is greater than the critical values at 1%. Hence, stationarity has not yet been achieved.

# %% [markdown]
# As, the data depicts seasonal behaviour as well, we perform second differencing too and try to achieve stationarity.

# %%
df2["2nd difference"]=df2["1st difference"].diff()
# Out:
# <ipython-input-24-30b04914d411>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["2nd difference"]=df2["1st difference"].diff()

# %%
df2.head()
# Out:
#               Month  Passengers  Moving Average        MA2       log  \
# year
# 1949-12-01  1949-12         118      126.666667  13.720147  4.770685
# 1950-01-01  1950-01         115      126.916667  13.453342  4.744932
# 1950-02-01  1950-02         126      127.583333  13.166475  4.836282
# 1950-03-01  1950-03         141      128.333333  13.686977  4.948760
# 1950-04-01  1950-04         135      128.833333  13.822467  4.905275
#
#             1st difference  2nd difference
# year
# 1949-12-01        0.126294             NaN
# 1950-01-01       -0.025752       -0.152046
# 1950-02-01        0.091350        0.117102
# 1950-03-01        0.112478        0.021128
# 1950-04-01       -0.043485       -0.155963

# %%
df3=df2.dropna(axis=0)

# %%
adfuller(df3["2nd difference"])
# Out:
# (-7.840593951996063,
#  5.951644141515415e-12,
#  13,
#  118,
#  {'1%': -3.4870216863700767,
#   '5%': -2.8863625166643136,
#   '10%': -2.580009026141913},
#  -406.663107068852)

# %% [markdown]
# The test statistic is less than critical values for all significance levels. Hence , stationarity has been achieved.

# %%
df2["1st difference"].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# The upward trend is seen to have been removed. But seasonal variations are still visible

# %%
df3["2nd difference"].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Now, the seasonal variations have also been removed.

# %% [markdown]
# ### ACF AND PACF Plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df3["2nd difference"])
plt.show()

# %%
plot_pacf(df3["2nd difference"])
plt.show()

# %% [markdown]
# Finding the order of ARMA model by iterating

# %%
from statsmodels.tsa.arima_model import ARMA
import itertools

# %%
p=q=range(0,8)
pq=list(itertools.product(p,q))
list1=[]
list2=[]
for order in pq:
    try:
        model=ARMA(df3["2nd difference"],order=order)
        model_fit=model.fit()
        list1.append(order)
        list2.append(model_fit.aic)
    except: 
        continue
# Out:
# C:\Users\vasu\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
dlist1=pd.DataFrame(list1)
dlist1.rename(columns={0:"p",1:"q"},inplace=True)
dlist2=pd.DataFrame(list2)
dlist2.rename(columns={0:"Aic"},inplace=True)
table=pd.concat([dlist1,dlist2],axis=1)

# %%
table
# Out:
#     p  q         Aic
# 0   0  0 -148.731168
# 1   0  1 -203.667863
# 2   0  2 -209.085428
# 3   0  3 -211.653265
# 4   0  4 -223.128006
# 5   0  5 -243.728872
# 6   0  6 -245.464710
# 7   0  7 -248.884391
# 8   1  0 -159.028889
# 9   2  0 -169.565361
# 10  2  1 -208.516693
# 11  2  2 -212.957552
# 12  3  0 -168.342555
# 13  3  1 -207.351567
# 14  3  2 -211.057904
# 15  4  0 -186.101450
# 16  4  1 -219.519566
# 17  4  2 -217.569324
# 18  5  0 -189.168148
# 19  5  1 -217.547031
# 20  5  2 -219.111194
# 21  5  4 -235.962088
# 22  6  0 -188.540194
# 23  6  1 -216.148119
# 24  6  2 -218.004932
# 25  6  4 -249.522304
# 26  7  0 -188.786769
# 27  7  1 -218.636961
# 28  7  2 -257.360610
# 29  7  4 -261.865263

# %%
table["Aic"].min()
# Out:
# -261.86526291754825

# %% [markdown]
# Finding the order corresponding to minimum AIC

# %%
data=table.query("Aic==Aic.min()")

# %%
data
# Out:
#     p  q         Aic
# 29  7  4 -261.865263

# %% [markdown]
# Hence order is (7,4)

# %% [markdown]
# Fitting the model

# %%
model2=ARMA(df3["2nd difference"],order=(7,4))
# Out:
# C:\Users\vasu\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
model2_fit=model2.fit()
# Out:
# C:\Users\vasu\anaconda3\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\vasu\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
pred=model2_fit.predict(start='1950-01-01',end='1960-12-01')

# %% [markdown]
# Plotting the predicted values  against the actual values

# %%
df2["2nd difference"].plot()
pred.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# The fit is good.

# %% [markdown]
# Scaling back the data

# %%
pr=model2_fit.predict()

# %%
pr1=pr.to_frame()

# %%
pr2= pr1[0]+df2["1st difference"].shift(12)

# %%
pr3= pr2+ df1["log"].shift(12)

# %%
pr3
# Out:
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
#                 ...
# 1960-08-01    6.187236
# 1960-09-01    5.956095
# 1960-10-01    5.922281
# 1960-11-01    5.788725
# 1960-12-01    6.391986
# Length: 144, dtype: float64

# %%
pr4=np.exp(pr3)

# %% [markdown]
# Plotting Actual vs Predicted data (ijn original form)

# %%
df3['Passengers'].plot()
pr4.plot()
plt.legend(["Actual", "Predicted"])

# %% [markdown]
# ### Model Error

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE=mean_squared_error(df3["Passengers"][12:],pr4[24:])

# %%
print("The Root Mean Square Error (RMSE) is", np.sqrt(MSE))
# Out:
# The Root Mean Square Error (RMSE) is 66.06201048788249

# %%
df3["Passengers"].mean()
# Out:
# 294.2651515151515

# %% [markdown]
# Since the RMSE is comparatively less than the mean of the time seires, the model's fits considered to be good.

# %% [markdown]
# ### Forecasting

# %%
forecast=model2_fit.predict(start='1961-01-01',end='1961-12-01')

# %%
forecast
# Out:
# 1960-12-01    0.275856
# 1961-01-01   -0.026507
# 1961-02-01   -0.084634
# 1961-03-01    0.141840
# 1961-04-01   -0.021693
# 1961-05-01   -0.138934
# 1961-06-01    0.072346
# 1961-07-01   -0.051637
# 1961-08-01   -0.102266
# 1961-09-01    0.112162
# 1961-10-01   -0.000187
# 1961-11-01   -0.069651
# 1961-12-01    0.116611
# Freq: MS, dtype: float64

# %%
f1=forecast.to_frame()

# %%
f1.rename(columns={0:"2 diff"},inplace=True)

# %%
p=df3["1st difference"][-1]

# %%
p
# Out:
# 0.10227884912041851

# %%
f1["1 diff"]=np.NaN
f1["1 diff"][0]=p

# %%
for i in range(1,12):
    f1["1 diff"][i]= f1["1 diff"][i-1]-f1["2 diff"][i]

# %%
f1["log values"]=np.NaN

# %%
p2=df3["log"][-2]

# %%
f1["log values"][0]=p2
for i in range(1,12):
    f1["log values"][i]= f1["log values"][i-1]-f1["1 diff"][i]

# %%
f1
# Out:
#               2 diff    1 diff  log values
# 1961-01-01 -0.026507  0.102279    5.966147
# 1961-02-01 -0.084634  0.186913    5.779234
# 1961-03-01  0.141840  0.045072    5.734162
# 1961-04-01 -0.021693  0.066765    5.667397
# 1961-05-01 -0.138934  0.205700    5.461697
# 1961-06-01  0.072346  0.133353    5.328344
# 1961-07-01 -0.051637  0.184991    5.143353
# 1961-08-01 -0.102266  0.287257    4.856097
# 1961-09-01  0.112162  0.175095    4.681002
# 1961-10-01 -0.000187  0.175282    4.505720
# 1961-11-01 -0.069651  0.244933    4.260787
# 1961-12-01  0.116611  0.128322    4.132465

# %%
f1["forecasted scaled back values"]=np.exp(f1["log values"])

# %% [markdown]
# The forecast for one year ahead is given by :

# %%
f1
# Out:
#               2 diff    1 diff  log values  forecasted scaled back values
# 1961-01-01 -0.026507  0.102279    5.966147                     390.000000
# 1961-02-01 -0.084634  0.186913    5.779234                     323.511349
# 1961-03-01  0.141840  0.045072    5.734162                     309.253714
# 1961-04-01 -0.021693  0.066765    5.667397                     289.280478
# 1961-05-01 -0.138934  0.205700    5.461697                     235.496777
# 1961-06-01  0.072346  0.133353    5.328344                     206.096370
# 1961-07-01 -0.051637  0.184991    5.143353                     171.289199
# 1961-08-01 -0.102266  0.287257    4.856097                     128.521557
# 1961-09-01  0.112162  0.175095    4.681002                     107.878065
# 1961-10-01 -0.000187  0.175282    4.505720                      90.533463
# 1961-11-01 -0.069651  0.244933    4.260787                      70.865731
# 1961-12-01  0.116611  0.128322    4.132465                      62.331381
